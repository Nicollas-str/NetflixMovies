# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Introdução;</li>
#   <li>Análise Exploratória de Dados;</li>
#   <li>Visualização Interativa de Dados;</li>
#   <li>Storytelling.</li>
# </ol>

# %% [markdown]
# ## 1\. Contexto

# %% [markdown]
# Um projeto requisitado pela EBAC(Escola britânica de artes criativas & tecnologia) de um dashboard com o tema aberto, a proposta é pegar um dataset do Kaggle, limpa-lo e com isso criar um dashboard usando o Google Looker Studio.
#
# Sabendo disso utilizei um dataset que foi baixado diretamente do Kaggle como csv e usei o arquivo diretamente do meu sistema no projeto, que tem os dados de séries e filmes assistidos semanalmente na Netflix e um rank deles de 1 à 10 e também temos o episódio da série em alta junto com a posição do filme/série.

# %% [markdown]
# ## 2\. Pacotes e bibliotecas

# %%
# Bibliotecas usadas no projeto

import requests
import bs4
import pandas as pd

# %% [markdown]
# ## 3\. Extração

# %%
# Colocando os dados em um Pandas

netflix = pd.read_csv("all-weeks-countries.csv", encoding="latin-1")

# %% [markdown]
# ## 4\. Visualização

# %%
# Visualizando os dados e como tudo está organizado para tomar as decisões de limpeza

netflix.head()
# Out:
#   country_name country_iso2        week category  weekly_rank  \
# 0    Argentina           AR  2023-11-19    Films            1
# 1    Argentina           AR  2023-11-19    Films            2
# 2    Argentina           AR  2023-11-19    Films            3
# 3    Argentina           AR  2023-11-19    Films            4
# 4    Argentina           AR  2023-11-19    Films            5
#
#                show_title season_title  cumulative_weeks_in_top_10
# 0              The Killer          NaN                           2
# 1    Mam? se fue de viaje          NaN                           2
# 2          Monster Hunter          NaN                           1
# 3       F9: The Fast Saga          NaN                           2
# 4  Best. Christmas. Ever!          NaN                           1

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233200 entries, 0 to 233199
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   country_name                233200 non-null  object
#  1   country_iso2                233200 non-null  object
#  2   week                        233200 non-null  object
#  3   category                    233200 non-null  object
#  4   weekly_rank                 233200 non-null  int64
#  5   show_title                  233200 non-null  object
#  6   season_title                112840 non-null  object
#  7   cumulative_weeks_in_top_10  233200 non-null  int64
# dtypes: int64(2), object(6)
# memory usage: 14.2+ MB

# %% [markdown]
# ## 5\. Limpeza

# %%
# Renomeando as colunas para ficarem mais coesas

netflix.columns = ["País", "Sigla_País", "Semana", "Categoria", "Rank_Semanal", "Titulo", "Titulo_episodio", "Consecutivos_top10"]

# %%
# Alterando os dados nulos para "desconhecido"

netflix["Titulo_episodio"].fillna("desconhecido", inplace=True)

# %%
netflix.head()
# Out:
#         País Sigla_País      Semana Categoria  Rank_Semanal  \
# 0  Argentina         AR  2023-11-19     Films             1
# 1  Argentina         AR  2023-11-19     Films             2
# 2  Argentina         AR  2023-11-19     Films             3
# 3  Argentina         AR  2023-11-19     Films             4
# 4  Argentina         AR  2023-11-19     Films             5
#
#                    Titulo Titulo_episodio  Consecutivos_top10
# 0              The Killer    desconhecido                   2
# 1    Mam? se fue de viaje    desconhecido                   2
# 2          Monster Hunter    desconhecido                   1
# 3       F9: The Fast Saga    desconhecido                   2
# 4  Best. Christmas. Ever!    desconhecido                   1

# %% [markdown]
# ## 5\. Carregamento

# %%
# Carregando os dados para outro CSV para assim fazer a análise usando um dashboard
netflix.to_csv("netflix.csv", index=False)
